# %%
import pandas as pd

# %%
df=pd.read_csv('wind_dataset.csv')
df.head()
# Out:
#          DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0  1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1  1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2  1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3  1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4  1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     6574 non-null   object
#  1   WIND     6574 non-null   float64
#  2   IND      6574 non-null   int64
#  3   RAIN     6574 non-null   float64
#  4   IND.1    6513 non-null   float64
#  5   T.MAX    5953 non-null   float64
#  6   IND.2    6513 non-null   float64
#  7   T.MIN    5900 non-null   float64
#  8   T.MIN.G  6214 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 462.4+ KB

# %%
df.isnull().sum()
# Out:
# DATE         0
# WIND         0
# IND          0
# RAIN         0
# IND.1       61
# T.MAX      621
# IND.2       61
# T.MIN      674
# T.MIN.G    360
# dtype: int64

# %%
df.describe()
# Out:
#               WIND          IND         RAIN        IND.1        T.MAX  \
# count  6574.000000  6574.000000  6574.000000  6513.000000  5953.000000
# mean      9.796834     0.391542     1.885169     0.356364    13.339123
# std       4.977272     1.179092     4.030529     1.128552     4.890546
# min       0.000000     0.000000     0.000000     0.000000    -0.100000
# 25%       6.000000     0.000000     0.000000     0.000000     9.600000
# 50%       9.210000     0.000000     0.200000     0.000000    13.300000
# 75%      12.960000     0.000000     2.000000     0.000000    17.200000
# max      30.370000     4.000000    67.000000     4.000000    26.800000
#
#              IND.2        T.MIN      T.MIN.G
# count  6513.000000  5900.000000  6214.000000
# mean      0.464456     6.411678     2.736547
# std       1.177571     4.637243     5.569175
# min       0.000000   -11.500000   -14.400000
# 25%       0.000000     3.000000    -1.000000
# 50%       0.000000     6.500000     3.000000
# 75%       0.000000    10.000000     7.000000
# max       4.000000    18.000000    15.800000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     6574 non-null   object
#  1   WIND     6574 non-null   float64
#  2   IND      6574 non-null   int64
#  3   RAIN     6574 non-null   float64
#  4   IND.1    6513 non-null   float64
#  5   T.MAX    5953 non-null   float64
#  6   IND.2    6513 non-null   float64
#  7   T.MIN    5900 non-null   float64
#  8   T.MIN.G  6214 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 462.4+ KB

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
df.isnull().sum()
# Out:
# DATE       0
# WIND       0
# IND        0
# RAIN       0
# IND.1      0
# T.MAX      0
# IND.2      0
# T.MIN      0
# T.MIN.G    0
# dtype: int64

# %%
# DATE column ला datetime format मध्ये convert करणे
df["DATE"] = pd.to_datetime(df["DATE"], format='%Y-%m-%d', errors='coerce')

# Check format
print(df.dtypes)
# Out:
# DATE       datetime64[ns]
# WIND              float64
# IND                 int64
# RAIN              float64
# IND.1             float64
# T.MAX             float64
# IND.2             float64
# T.MIN             float64
# T.MIN.G           float64
# dtype: object

# %%
# date convert to datetime
df["DATE"] = pd.to_datetime(df["DATE"])

# convert date to numeric timestamp (seconds since 1970)
df["DATE"] = df["DATE"].astype('int64') // 10**9

print(df.head())
# Out:
#         DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0 -283996800  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1 -283910400  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2 -283824000  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3 -283737600   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4 -283651200  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5
